# %%
# Assignment number 9:
# Load the Titanic dataset
# Display basic information
# Display statistical information
# Display null values
# Fill the null values
# Display and interpret boxplot of one variable, two variables and three variablesz

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading dataset
df = pd.read_csv('titanic.csv')

# %%
# Display basic information
print('Information of Dataset:\n', df.info())
print('Shape of Dataset (row x column): ', df.shape)
print('Columns Name: ', df.columns)
print('Total elements in dataset:', df.size)
print('Datatype of attributes (columns):', df.dtypes)
print('First 5 rows:\n', df.head().T)
print('Last 5 rows:\n',df.tail().T)
print('Any 5 rows:\n',df.sample(5).T)

# Display Statistical information
print('\nStatistical information of Numerical Columns: \n',df.describe())

# Display and fill the Null values
print('\nTotal Number of Null Values in Dataset:', df.isna().sum())
df['Age'].fillna(df['Age'].median(), inplace=True)
df['Embarked'].fillna(df['Embarked'].mode()[0], inplace=True)
print('\nTotal Number of Null Values in Dataset After Filling:', df.isna().sum())

# One variable
fig, axes = plt.subplots(1,2, figsize=(12,6))
sns.boxplot(data = df, y ='Age', ax=axes[0])
sns.boxplot(data = df, y ='Fare', ax=axes[1])
plt.show()

# Two variables
fig, axes = plt.subplots(1,3, sharey=True, figsize=(15,6))
sns.boxplot(data = df, x='Sex', y ='Age', hue = 'Sex', ax=axes[0])
sns.boxplot(data = df, x='Pclass', y ='Age', hue = 'Pclass', ax=axes[1])
sns.boxplot(data = df, x='Survived', y ='Age', hue = 'Survived', ax=axes[2])
plt.show()

# Two variables
fig, axes = plt.subplots(1,3, sharey=True, figsize=(15,6))
sns.boxplot(data = df, x='Sex', y ='Fare', hue = 'Sex', ax=axes[0])
axes[0].set_yscale('log')
sns.boxplot(data = df, x='Pclass', y ='Fare', hue = 'Pclass', ax=axes[1])
axes[1].set_yscale('log')
sns.boxplot(data = df, x='Survived', y ='Fare', hue = 'Survived', ax=axes[2])
axes[2].set_yscale('log')
plt.show()

fig, axes = plt.subplots(1,2, sharey=True, figsize=(12,6))
sns.boxplot(data = df, x='Sex', y ='Fare', hue = 'Survived', ax=axes[0])
plt.gca().set_yscale('log')
sns.boxplot(data = df, x='Pclass', y ='Fare', hue = 'Survived', ax=axes[1])
plt.gca().set_yscale('log')
plt.show()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156 entries, 0 to 155
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  156 non-null    int64
#  1   Survived     156 non-null    int64
#  2   Pclass       156 non-null    int64
#  3   Lname        156 non-null    object
#  4   Name         156 non-null    object
#  5   Sex          156 non-null    object
#  6   Age          126 non-null    float64
#  7   SibSp        156 non-null    int64
#  8   Parch        156 non-null    int64
#  9   Ticket       156 non-null    object
#  10  Fare         156 non-null    float64
#  11  Cabin        31 non-null     object
#  12  Embarked     155 non-null    object
# dtypes: float64(2), int64(5), object(6)
# memory usage: 16.0+ KB
# Information of Dataset:
#  None
# Shape of Dataset (row x column):  (156, 13)
# Columns Name:  Index(['PassengerId', 'Survived', 'Pclass', 'Lname', 'Name', 'Sex', 'Age',
#        'SibSp', 'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')
# Total elements in dataset: 2028
# Datatype of attributes (columns): PassengerId      int64
# Survived         int64
# Pclass           int64
# Lname           object
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
# First 5 rows:
#                              0                                            1  \
# PassengerId                 1                                            2
# Survived                    0                                            1
# Pclass                      3                                            1
# Lname                  Braund                                      Cumings
# Name          Mr. Owen Harris   Mrs. John Bradley (Florence Briggs Thayer)
# Sex                      male                                       female
# Age                      22.0                                         38.0
# SibSp                       1                                            1
# Parch                       0                                            0
# Ticket              A/5 21171                                     PC 17599
# Fare                     7.25                                      71.2833
# Cabin                     NaN                                          C85
# Embarked                    S                                            C
#
#                             2                                    3  \
# PassengerId                 3                                    4
# Survived                    1                                    1
# Pclass                      3                                    1
# Lname               Heikkinen                             Futrelle
# Name              Miss. Laina   Mrs. Jacques Heath (Lily May Peel)
# Sex                    female                               female
# Age                      26.0                                 35.0
# SibSp                       0                                    1
# Parch                       0                                    0
# Ticket       STON/O2. 3101282                               113803
# Fare                    7.925                                 53.1
# Cabin                     NaN                                 C123
# Embarked                    S                                    S
#
#                               4
# PassengerId                   5
# Survived                      0
# Pclass                        3
# Lname                     Allen
# Name          Mr. William Henry
# Sex                        male
# Age                        35.0
# SibSp                         0
# Parch                         0
# Ticket                   373450
# Fare                       8.05
# Cabin                       NaN
# Embarked                      S
# Last 5 rows:
#                                       151           152                 153  \
# PassengerId                          152           153                 154
# Survived                               1             0                   0
# Pclass                                 1             3                   3
# Lname                              Pears           Meo        van Billiard
# Name          Mrs. Thomas (Edith Wearne)   Mr. Alfonzo   Mr. Austin Blyler
# Sex                               female          male                male
# Age                                 22.0          55.5                40.5
# SibSp                                  1             0                   0
# Parch                                  0             0                   2
# Ticket                            113776    A.5. 11206            A/5. 851
# Fare                                66.6          8.05                14.5
# Cabin                                 C2           NaN                 NaN
# Embarked                               S             S                   S
#
#                          154                 155
# PassengerId              155                 156
# Survived                   0                   0
# Pclass                     3                   1
# Lname                  Olsen            Williams
# Name          Mr. Ole Martin   Mr. Charles Duane
# Sex                     male                male
# Age                      NaN                51.0
# SibSp                      0                   0
# Parch                      0                   1
# Ticket             Fa 265302            PC 17597
# Fare                  7.3125             61.3792
# Cabin                    NaN                 NaN
# Embarked                   S                   C
# Any 5 rows:
#                                                     18         108  \
# PassengerId                                         19        109
# Survived                                             0          0
# Pclass                                               3          3
# Lname                                    Vander Planke      Rekic
# Name          Mrs. Julius (Emelia Maria Vandemoortele)   Mr. Tido
# Sex                                             female       male
# Age                                               31.0       38.0
# SibSp                                                1          0
# Parch                                                0          0
# Ticket                                          345763     349249
# Fare                                              18.0     7.8958
# Cabin                                              NaN        NaN
# Embarked                                             S          S
#
#                                  110            20         55
# PassengerId                      111             21         56
# Survived                           0              0          1
# Pclass                             1              2          1
# Lname                         Porter         Fynney    Woolner
# Name          Mr. Walter Chamberlain   Mr. Joseph J   Mr. Hugh
# Sex                             male           male       male
# Age                             47.0           35.0        NaN
# SibSp                              0              0          0
# Parch                              0              0          0
# Ticket                        110465         239865      19947
# Fare                            52.0           26.0       35.5
# Cabin                           C110            NaN        C52
# Embarked                           S              S          S
#
# Statistical information of Numerical Columns:
#         PassengerId    Survived      Pclass         Age       SibSp  \
# count   156.000000  156.000000  156.000000  126.000000  156.000000
# mean     78.500000    0.346154    2.423077   28.141508    0.615385
# std      45.177428    0.477275    0.795459   14.613880    1.056235
# min       1.000000    0.000000    1.000000    0.830000    0.000000
# 25%      39.750000    0.000000    2.000000   19.000000    0.000000
# 50%      78.500000    0.000000    3.000000   26.000000    0.000000
# 75%     117.250000    1.000000    3.000000   35.000000    1.000000
# max     156.000000    1.000000    3.000000   71.000000    5.000000
#
#             Parch        Fare
# count  156.000000  156.000000
# mean     0.397436   28.109587
# std      0.870146   39.401047
# min      0.000000    6.750000
# 25%      0.000000    8.003150
# 50%      0.000000   14.454200
# 75%      0.000000   30.371850
# max      5.000000  263.000000
#
# Total Number of Null Values in Dataset: PassengerId      0
# Survived         0
# Pclass           0
# Lname            0
# Name             0
# Sex              0
# Age             30
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          125
# Embarked         1
# dtype: int64
#
# Total Number of Null Values in Dataset After Filling: PassengerId      0
# Survived         0
# Pclass           0
# Lname            0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          125
# Embarked         0
# dtype: int64
